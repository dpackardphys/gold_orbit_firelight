# %%
import numpy as np
import pandas as pd


import json
import requests
from pprint import pprint

# %%
file_path = "Resources/Chicago_Health_Youth_activity.csv"
youth_activity_df= pd.read_csv(file_path)
youth_activity_df
# Out:
#   Layer         Name      GEOID  \
# 0   NaN          NaN        NaN
# 1  City  Chicago, IL  1714000.0
# 2  City  Chicago, IL  1714000.0
#
#                                            YRPA_2019  \
# 0  Youth physical activity (count of students), 2019
# 1                                            10000.0
# 2                                            10000.0
#
#                                            YRPA_2017  \
# 0  Youth physical activity (count of students), 2017
# 1                                            11400.0
# 2                                            11400.0
#
#                                            YRPA_2013  \
# 0  Youth physical activity (count of students), 2013
# 1                                            14900.0
# 2                                            14900.0
#
#                                            YRPA_2011  \
# 0  Youth physical activity (count of students), 2011
# 1                                            14100.0
# 2                                            14100.0
#
#                                            YRPA_2009  \
# 0  Youth physical activity (count of students), 2009
# 1                                            15500.0
# 2                                            15500.0
#
#                                            YRPA_2007  \
# 0  Youth physical activity (count of students), 2007
# 1                                            13100.0
# 2                                            13100.0
#
#                                            YRPA_2005  \
# 0  Youth physical activity (count of students), 2005
# 1                                            10300.0
# 2                                            10300.0
#
#                                           YRPAP_2019  \
# 0  Youth physical activity rate (% of students), ...
# 1                                               15.0
# 2                                               15.0
#
#                                           YRPAP_2017  \
# 0  Youth physical activity rate (% of students), ...
# 1                                               17.2
# 2                                               17.2
#
#                                           YRPAP_2013  \
# 0  Youth physical activity rate (% of students), ...
# 1                                               19.6
# 2                                               19.6
#
#                                           YRPAP_2011  \
# 0  Youth physical activity rate (% of students), ...
# 1                                               18.2
# 2                                               18.2
#
#                                           YRPAP_2009  \
# 0  Youth physical activity rate (% of students), ...
# 1                                               17.5
# 2                                               17.5
#
#                                           YRPAP_2007  \
# 0  Youth physical activity rate (% of students), ...
# 1                                               16.4
# 2                                               16.4
#
#                                           YRPAP_2005  \
# 0  Youth physical activity rate (% of students), ...
# 1                                               12.5
# 2                                               12.5
#
#                                          YRPA-M_2019
# 0  Youth physical activity, Males (count of stude...
# 1                                             5700.0
# 2                                             5700.0

# %%
file_path2 = "Resources/Chicago_Health_Atlas_youth_diet.csv"
youth_diet_df= pd.read_csv(file_path2)
youth_diet_df
# Out:
#   Layer         Name      GEOID  \
# 0   NaN          NaN        NaN
# 1  City  Chicago, IL  1714000.0
# 2  City  Chicago, IL  1714000.0
#
#                                            YRFV_2019  \
# 0  Youth fruit and vegetable servings (count of s...
# 1                                            10600.0
# 2                                            10600.0
#
#                                            YRFV_2017  \
# 0  Youth fruit and vegetable servings (count of s...
# 1                                            11900.0
# 2                                            11900.0
#
#                                            YRFV_2013  \
# 0  Youth fruit and vegetable servings (count of s...
# 1                                            13600.0
# 2                                            13600.0
#
#                                            YRFV_2011  \
# 0  Youth fruit and vegetable servings (count of s...
# 1                                            16300.0
# 2                                            16300.0
#
#                                            YRFV_2009  \
# 0  Youth fruit and vegetable servings (count of s...
# 1                                            19700.0
# 2                                            19700.0
#
#                                            YRFV_2007  \
# 0  Youth fruit and vegetable servings (count of s...
# 1                                            16000.0
# 2                                            16000.0
#
#                                            YRFV_2005  ...  \
# 0  Youth fruit and vegetable servings (count of s...  ...
# 1                                            18200.0  ...
# 2                                            18200.0  ...
#
#                                            YRFV_2001  \
# 0  Youth fruit and vegetable servings (count of s...
# 1                                            26900.0
# 2                                            26900.0
#
#                                           YRFVP_2019  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               16.2
# 2                                               16.2
#
#                                           YRFVP_2017  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               18.1
# 2                                               18.1
#
#                                           YRFVP_2013  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               18.3
# 2                                               18.3
#
#                                           YRFVP_2011  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               21.6
# 2                                               21.6
#
#                                           YRFVP_2009  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               22.6
# 2                                               22.6
#
#                                           YRFVP_2007  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               20.4
# 2                                               20.4
#
#                                           YRFVP_2005  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               22.1
# 2                                               22.1
#
#                                           YRFVP_2003  \
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               17.7
# 2                                               17.7
#
#                                           YRFVP_2001
# 0  Youth fruit and vegetable servings rate (% of ...
# 1                                               29.5
# 2                                               29.5
#
# [3 rows x 21 columns]

# %%
file_path3 = "Resources/Chicago_Health_Atlas_youth_drinking.csv"
youth_drinking_df= pd.read_csv(file_path3)
youth_drinking_df
# Out:
#   Layer         Name      GEOID  \
# 0   NaN          NaN        NaN
# 1  City  Chicago, IL  1714000.0
# 2  City  Chicago, IL  1714000.0
#
#                                         YRBD_2019  \
# 0  Youth binge drinking (count of students), 2019
# 1                                          5000.0
# 2                                          5000.0
#
#                                         YRBD_2017  \
# 0  Youth binge drinking (count of students), 2017
# 1                                          5900.0
# 2                                          5900.0
#
#                                         YRBDP_2019  \
# 0  Youth binge drinking rate (% of students), 2019
# 1                                              8.0
# 2                                              8.0
#
#                                         YRBDP_2017
# 0  Youth binge drinking rate (% of students), 2017
# 1                                              9.1
# 2                                              9.1

# %%
file_path4 = "Resources/Chicago_Health_Atlas_opiate_misuse.csv"
opiate_misuse_df= pd.read_csv(file_path4)
opiate_misuse_df
# Out:
#              Layer             Name  GEOID  \
# 0              NaN              NaN    NaN
# 1   Community area      Rogers Park    1.0
# 2   Community area        West Town   24.0
# 3   Community area           Uptown    3.0
# 4   Community area          Chatham   44.0
# 5   Community area    Brighton Park   58.0
# 6   Community area        Lake View    6.0
# 7   Community area        Englewood   68.0
# 8   Community area     Lincoln Park    7.0
# 9   Community area        Edgewater   77.0
# 10  Community area  Near North Side    8.0
#
#                                       HCSOP_2020-2021  \
# 0   Prescription opiate misuse (count of adults), ...
# 1                                              1900.0
# 2                                              1900.0
# 3                                              1600.0
# 4                                              1100.0
# 5                                              5200.0
# 6                                               800.0
# 7                                               500.0
# 8                                              1700.0
# 9                                              1100.0
# 10                                              600.0
#
#                                      HCSOPP_2020-2021
# 0   Prescription opiate misuse rate (% of adults),...
# 1                                        4.4232389536
# 2                                        2.7311818652
# 3                                        3.5060364082
# 4                                        4.3179203983
# 5                                        13.415020344
# 6                                        0.9268238067
# 7                                        2.5386950864
# 8                                        2.9174861589
# 9                                        2.0828959464
# 10                                       0.7553315314
