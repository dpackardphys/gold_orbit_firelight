# %%
import numpy as np
import pandas as pd


import json
import requests
from pprint import pprint

# %%
file_path = "Resources/YSARC.csv"
school_df= pd.read_csv(file_path)
school_df
# Out:
#   Layer         Name      GEOID  \
# 0   NaN          NaN        NaN
# 1  City  Chicago, IL  1714000.0
# 2  City  Chicago, IL  1714000.0
#
#                                           YRSUP_2019         YRSUP_2019_moe
# 0  Youth suicide attempts rate (% of students), 2019  (90% margin of error)
# 1                                                3.4          0.96517857163
# 2                                                3.4          0.96517857163

# %%
file_path2 = "Resources/SSRC.csv"
safety_df= pd.read_csv(file_path2)
safety_df
# Out:
#   Layer         Name      GEOID                               YRSAFP_2019  \
# 0   NaN          NaN        NaN  School safety rate (% of students), 2019
# 1  City  Chicago, IL  1714000.0                                      12.8
# 2  City  Chicago, IL  1714000.0                                      12.8
#
#          YRSAFP_2019_moe
# 0  (90% margin of error)
# 1         3.399107143495
# 2         3.399107143495

# %%
file_path3 = "Resources/SSVIC.csv"
county_df= pd.read_csv(file_path3)
county_df
# Out:
#              Layer             Name  GEOID  \
# 0              NaN              NaN    NaN
# 1   Community area      Rogers Park    1.0
# 2   Community area     Norwood Park   10.0
# 3   Community area   Jefferson Park   11.0
# 4   Community area      Forest Glen   12.0
# ..             ...              ...    ...
# 73  Community area      Morgan Park   75.0
# 74  Community area           O'Hare   76.0
# 75  Community area        Edgewater   77.0
# 76  Community area  Near North Side    8.0
# 77  Community area      Edison Park    9.0
#
#                                          SVI_2018           SVI_2018_moe
# 0   Social Vulnerability Index (percentile), 2018  (90% margin of error)
# 1                                 74.252711166267                    NaN
# 2                                28.1600046000414                    NaN
# 3                                41.0611729629026                    NaN
# 4                                17.5502845745532                    NaN
# ..                                            ...                    ...
# 73                               57.4850447001788                    NaN
# 74                               57.4095078595596                    NaN
# 75                               46.5277661622338                    NaN
# 76                                    21.21524105                    NaN
# 77                               5.10661807501455                    NaN
#
# [78 rows x 5 columns]

# %%
file_path4 = "Resources/CBRD.csv"
belonging_df= pd.read_csv(file_path4)
belonging_df
# Out:
#              Layer             Name  GEOID  \
# 0              NaN              NaN    NaN
# 1   Community area      Rogers Park    1.0
# 2   Community area     Norwood Park   10.0
# 3   Community area   Jefferson Park   11.0
# 4   Community area      Forest Glen   12.0
# ..             ...              ...    ...
# 73  Community area      Morgan Park   75.0
# 74  Community area           O'Hare   76.0
# 75  Community area        Edgewater   77.0
# 76  Community area  Near North Side    8.0
# 77  Community area      Edison Park    9.0
#
#                                      HCSCBP_2020-2021   HCSCBP_2020-2021_moe
# 0   Community belonging rate (% of adults), 2020-2021  (90% margin of error)
# 1                                        39.856683747      7.559755139691999
# 2                                        55.009256357        10.269752311322
# 3                                         52.51604687         12.27374862707
# 4                                        70.491910862        13.863470337906
# ..                                                ...                    ...
# 73                                       62.290987599     15.548622128105501
# 74                                       55.340499009         18.25943065009
# 75                                       50.091956516      6.512196221387501
# 76                                       40.539485666        5.3228257821655
# 77                                       59.249981711       13.1204258485895
#
# [78 rows x 5 columns]
