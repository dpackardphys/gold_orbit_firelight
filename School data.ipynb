# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import json
import requests
from pprint import pprint

# %%
file_path = "Resources/DRUG.csv"
#Drug Induced Mortality
school_df= pd.read_csv(file_path)
school_df
# Out:
#     Category  Full population
# 0       2000              394
# 1       2001              348
# 2       2002              373
# 3       2003              305
# 4       2004              317
# 5       2005              337
# 6       2006              484
# 7       2007              320
# 8       2008              317
# 9       2009              308
# 10      2010              266
# 11      2011              213
# 12      2012              367
# 13      2013              392
# 14      2014              362
# 15      2015              414
# 16      2016              681
# 17      2017              762
# 18      2018              784
# 19      2019              865
# 20      2020             1248

# %%
file_path2 = "Resources/SSRIC.csv"
#School Safety Rate
safety_df= pd.read_csv(file_path2)
safety_df
# Out:
#    Category  Full population
# 0      2001             16.0
# 1      2003             13.6
# 2      2005             10.5
# 3      2007             12.3
# 4      2009             15.1
# 5      2011             10.8
# 6      2013             12.9
# 7      2015              NaN
# 8      2017             10.0
# 9      2019             12.8

# %%
file_path3 = "Resources/NSIC.csv"
#Neighborhood Safety
county_df= pd.read_csv(file_path3)
county_df
# Out:
#    Category  18-29 years  30-44 years  45-64 years  Seniors (65 and older)
# 0      2015     357000.0     481000.0     472000.0                268000.0
# 1      2016     342000.0     455000.0     441000.0                257000.0
# 2      2017     393000.0     471000.0     481000.0                268000.0
# 3      2018     392000.0     478000.0     486000.0                272000.0
# 4      2019          NaN          NaN          NaN                     NaN
# 5      2020     338000.0     419000.0     386000.0                218000.0
# 6      2021     312000.0     379000.0     371000.0                233000.0

# %%
file_path4 = "Resources/CBICA.csv"
#Community Belonging in Chicago All Ages
belonging_df= pd.read_csv(file_path4)
belonging_df
# Out:
#    Category  Full population
# 0      2015        1358000.0
# 1      2016        1245000.0
# 2      2017        1255000.0
# 3      2018        1324000.0
# 4      2019              NaN
# 5      2020         970000.0
# 6      2021         923000.0

# %%
file_path5 = "Resources/CBIYA.csv"
#Community Belonging in Chicago Young Ages
ump_df= pd.read_csv(file_path5)
ump_df
# Out:
#    Category  18-29 years
# 0      2015     263000.0
# 1      2016     244000.0
# 2      2017     248000.0
# 3      2018     244000.0
# 4      2019          NaN
# 5      2020     176000.0
# 6      2021     158000.0

# %%
file_path6 = "Resources/NSICA.csv"
#Neighborhood Safety
NSICA_df= pd.read_csv(file_path6)
NSICA_df
# Out:
#    Category  Full population
# 0      2015        1578000.0
# 1      2016        1494000.0
# 2      2017        1613000.0
# 3      2018        1629000.0
# 4      2019              NaN
# 5      2020        1364000.0
# 6      2021        1298000.0

# %%
ump_df.columns
# Out:
# Index(['Category', '18-29 years'], dtype='object')

# %%
file_path7 = "Resources/CBRIC.csv"
#Community Belonging in Chicago Adult Ages
allage_df= pd.read_csv(file_path7)
allage_df.head()
# Out:
#             Layer            Name  GEOID  \
# 0             NaN             NaN    NaN
# 1  Community area     Rogers Park    1.0
# 2  Community area    Norwood Park   10.0
# 3  Community area  Jefferson Park   11.0
# 4  Community area     Forest Glen   12.0
#
#                                     HCSCBP_2020-2021   HCSCBP_2020-2021_moe
# 0  Community belonging rate (% of adults), 2020-2021  (90% margin of error)
# 1                                       39.856683747      7.559755139691999
# 2                                       55.009256357        10.269752311322
# 3                                        52.51604687         12.27374862707
# 4                                       70.491910862        13.863470337906

# %%
file_path8 = "Resources/NSRIC.csv"
#Community Belonging in Chicago Older Ages
oldage_df= pd.read_csv(file_path8)
oldage_df
allage_df.head()
# Out:
#             Layer            Name  GEOID  \
# 0             NaN             NaN    NaN
# 1  Community area     Rogers Park    1.0
# 2  Community area    Norwood Park   10.0
# 3  Community area  Jefferson Park   11.0
# 4  Community area     Forest Glen   12.0
#
#                                     HCSCBP_2020-2021   HCSCBP_2020-2021_moe
# 0  Community belonging rate (% of adults), 2020-2021  (90% margin of error)
# 1                                       39.856683747      7.559755139691999
# 2                                       55.009256357        10.269752311322
# 3                                        52.51604687         12.27374862707
# 4                                       70.491910862        13.863470337906

# %%
pd.concat([allage_df,oldage_df], axis=1)
# Out:
#              Layer             Name  GEOID  \
# 0              NaN              NaN    NaN
# 1   Community area      Rogers Park    1.0
# 2   Community area     Norwood Park   10.0
# 3   Community area   Jefferson Park   11.0
# 4   Community area      Forest Glen   12.0
# ..             ...              ...    ...
# 73  Community area      Morgan Park   75.0
# 74  Community area           O'Hare   76.0
# 75  Community area        Edgewater   77.0
# 76  Community area  Near North Side    8.0
# 77  Community area      Edison Park    9.0
#
#                                      HCSCBP_2020-2021   HCSCBP_2020-2021_moe  \
# 0   Community belonging rate (% of adults), 2020-2021  (90% margin of error)
# 1                                        39.856683747      7.559755139691999
# 2                                        55.009256357        10.269752311322
# 3                                         52.51604687         12.27374862707
# 4                                        70.491910862        13.863470337906
# ..                                                ...                    ...
# 73                                       62.290987599     15.548622128105501
# 74                                       55.340499009         18.25943065009
# 75                                       50.091956516      6.512196221387501
# 76                                       40.539485666        5.3228257821655
# 77                                       59.249981711       13.1204258485895
#
#              Layer             Name  GEOID  \
# 0              NaN              NaN    NaN
# 1   Community area      Rogers Park    1.0
# 2   Community area     Norwood Park   10.0
# 3   Community area   Jefferson Park   11.0
# 4   Community area      Forest Glen   12.0
# ..             ...              ...    ...
# 73  Community area      Morgan Park   75.0
# 74  Community area           O'Hare   76.0
# 75  Community area        Edgewater   77.0
# 76  Community area  Near North Side    8.0
# 77  Community area      Edison Park    9.0
#
#                                      HCSNSP_2020-2021   HCSNSP_2020-2021_moe
# 0   Neighborhood safety rate (% of adults), 2020-2021  (90% margin of error)
# 1                                        63.219438399         8.355706930816
# 2                                         92.01992788         5.099395777735
# 3                                         87.74209975      8.788206781728501
# 4                                         98.81927334        1.4627860167095
# ..                                                ...                    ...
# 73                                       85.179779056         9.230437690677
# 74                                       75.300886448     16.688678939099997
# 75                                       88.728133094        4.0495151574255
# 76                                       72.006755804        4.6733247437555
# 77                                       96.172029349         3.365534462528
#
# [78 rows x 10 columns]

# %%
allage_df.merge(oldage_df,on=["Name"])
# Out:
#            Layer_x             Name  GEOID_x  \
# 0              NaN              NaN      NaN
# 1   Community area      Rogers Park      1.0
# 2   Community area     Norwood Park     10.0
# 3   Community area   Jefferson Park     11.0
# 4   Community area      Forest Glen     12.0
# ..             ...              ...      ...
# 73  Community area      Morgan Park     75.0
# 74  Community area           O'Hare     76.0
# 75  Community area        Edgewater     77.0
# 76  Community area  Near North Side      8.0
# 77  Community area      Edison Park      9.0
#
#                                      HCSCBP_2020-2021   HCSCBP_2020-2021_moe  \
# 0   Community belonging rate (% of adults), 2020-2021  (90% margin of error)
# 1                                        39.856683747      7.559755139691999
# 2                                        55.009256357        10.269752311322
# 3                                         52.51604687         12.27374862707
# 4                                        70.491910862        13.863470337906
# ..                                                ...                    ...
# 73                                       62.290987599     15.548622128105501
# 74                                       55.340499009         18.25943065009
# 75                                       50.091956516      6.512196221387501
# 76                                       40.539485666        5.3228257821655
# 77                                       59.249981711       13.1204258485895
#
#            Layer_y  GEOID_y  \
# 0              NaN      NaN
# 1   Community area      1.0
# 2   Community area     10.0
# 3   Community area     11.0
# 4   Community area     12.0
# ..             ...      ...
# 73  Community area     75.0
# 74  Community area     76.0
# 75  Community area     77.0
# 76  Community area      8.0
# 77  Community area      9.0
#
#                                      HCSNSP_2020-2021   HCSNSP_2020-2021_moe
# 0   Neighborhood safety rate (% of adults), 2020-2021  (90% margin of error)
# 1                                        63.219438399         8.355706930816
# 2                                         92.01992788         5.099395777735
# 3                                         87.74209975      8.788206781728501
# 4                                         98.81927334        1.4627860167095
# ..                                                ...                    ...
# 73                                       85.179779056         9.230437690677
# 74                                       75.300886448     16.688678939099997
# 75                                       88.728133094        4.0495151574255
# 76                                       72.006755804        4.6733247437555
# 77                                       96.172029349         3.365534462528
#
# [78 rows x 9 columns]

# %%
file_path9 = "Resources/CSSEMH.csv"
CSSEMH_df= pd.read_csv(file_path9)
CSSEMH_df.head()
# Out:
#    Community Area Number COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT HOUSEHOLDS BELOW POVERTY  PERCENT AGED 16+ UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                          18.2
# 1                                          20.8
# 2                                          11.8
# 3                                          13.4
# 4                                           4.5
#
#    PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME   HARDSHIP INDEX
# 0                              27.5               23939            39.0
# 1                              38.5               23040            46.0
# 2                              22.2               35787            20.0
# 3                              25.5               37524            17.0
# 4                              26.2               57123             6.0

# %%
cleaned_CSSEMH = CSSEMH_df.drop(index=[0,2],
                                                      columns=['Community Area Number','PERCENT AGED 16+ UNEMPLOYED','HARDSHIP INDEX'])


cleaned_CSSEMH
# Out:
#    COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 1           West Ridge                         7.8
# 3       Lincoln Square                         3.4
# 4         North Center                         0.3
# 5            Lake View                         1.1
# 6         Lincoln Park                         0.8
# ..                 ...                         ...
# 73     Mount Greenwood                         1.0
# 74         Morgan Park                         0.8
# 75              O'Hare                         3.6
# 76           Edgewater                         4.1
# 77             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  \
# 1                               17.2
# 3                               10.9
# 4                                7.5
# 5                               11.4
# 6                               12.3
# ..                               ...
# 73                               3.4
# 74                              13.2
# 75                              15.4
# 76                              18.2
# 77                              19.7
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 1                                           20.8
# 3                                           13.4
# 4                                            4.5
# 5                                            2.6
# 6                                            3.6
# ..                                           ...
# 73                                           4.3
# 74                                          10.8
# 75                                          10.9
# 76                                           9.7
# 77                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME
# 1                               38.5               23040
# 3                               25.5               37524
# 4                               26.2               57123
# 5                               17.0               60058
# 6                               21.5               71551
# ..                               ...                 ...
# 73                              36.8               34381
# 74                              40.3               27149
# 75                              30.3               25828
# 76                              23.8               33385
# 77                              33.5               28202
#
# [76 rows x 6 columns]

# %%
cleaned_CSSEMH.columns
# Out:
# Index(['COMMUNITY AREA NAME', 'PERCENT OF HOUSING CROWDED',
#        'PERCENT HOUSEHOLDS BELOW POVERTY',
#        'PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA',
#        'PERCENT AGED UNDER 18 OR OVER 64', 'PER CAPITA INCOME '],
#       dtype='object')

# %%
file_path10 = "Resources/SFRIC.csv"
SFRIC_df= pd.read_csv(file_path10)
SFRIC_df.head()
# Out:
#    Category  Full population
# 0      2001             18.5
# 1      2003             19.3
# 2      2005             19.5
# 3      2007             17.4
# 4      2009             20.6

# %%
file_path11 = "Resources/SBRIC.csv"
SBRIC_df= pd.read_csv(file_path11)
SBRIC_df.head()
# Out:
#    Category  Full population
# 0      2009             11.1
# 1      2011             12.8
# 2      2013             13.0
# 3      2015              NaN
# 4      2017             15.2

# %%
plt.rcParams['figure.figsize'] = [19, 7]
cleaned_CSSEMH.plot(kind='bar',x='COMMUNITY AREA NAME',y='PERCENT HOUSEHOLDS BELOW POVERTY', color='red')
plt.title("Poverty Rate by Neughborhood")
plt.show()

# %%
ax = plt.gca()
cleaned_CSSEMH.plot(kind='line',x='COMMUNITY AREA NAME',y='PERCENT HOUSEHOLDS BELOW POVERTY',ax=ax)
cleaned_CSSEMH.plot(kind='line',x='COMMUNITY AREA NAME',y='PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA', color='red', ax=ax)
plt.title("Households % Below Poverty vs Household % highschool dropouts ")
plt.show()

# %%
ax = plt.gca()
belonging_df.plot(kind='line',x='Category',y='Full population',ax=ax)
NSICA_df.plot(kind='line',x='Category',y='Full population', color='red', ax=ax)
plt.xlabel("Year")
plt.ylabel("Full Population (In Millions)")
plt.legend(['Community Belongng','Neighborhood safety'],loc='best')
plt.title("Community Belonging vs Neighborhood Safety")
plt.show()

# %%
ax = plt.gca()
SFRIC_df.plot(kind='line',x='Category',y='Full population',ax=ax)
safety_df.plot(kind='line',x='Category',y='Full population', color='red', ax=ax)
SBRIC_df.plot(kind='line',x='Category',y='Full population', color='Green', ax=ax)
plt.xlabel("Year")
plt.ylabel("Students(%)")
plt.legend(['School Fights','School Safety Ovr','School Bullying'],loc='best')
plt.title("School fights, School Bullying vs Overall School Safety")
plt.show()
