# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


import json
import requests
from pprint import pprint

# %%
file_path = "Resources/cleaned_CSSEMH.csv"
#Drug Induced Mortality
school_df= pd.read_csv(file_path)
school_df
# Out:
#     Unnamed: 0 COMMUNITY AREA NAME  PERCENT OF HOUSING CROWDED  \
# 0            1          West Ridge                         7.8
# 1            3      Lincoln Square                         3.4
# 2            4        North Center                         0.3
# 3            5           Lake View                         1.1
# 4            6        Lincoln Park                         0.8
# ..         ...                 ...                         ...
# 71          73     Mount Greenwood                         1.0
# 72          74         Morgan Park                         0.8
# 73          75              O'Hare                         3.6
# 74          76           Edgewater                         4.1
# 75          77             CHICAGO                         4.7
#
#     PERCENT HOUSEHOLDS BELOW POVERTY  \
# 0                               17.2
# 1                               10.9
# 2                                7.5
# 3                               11.4
# 4                               12.3
# ..                               ...
# 71                               3.4
# 72                              13.2
# 73                              15.4
# 74                              18.2
# 75                              19.7
#
#     PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA  \
# 0                                           20.8
# 1                                           13.4
# 2                                            4.5
# 3                                            2.6
# 4                                            3.6
# ..                                           ...
# 71                                           4.3
# 72                                          10.8
# 73                                          10.9
# 74                                           9.7
# 75                                          19.5
#
#     PERCENT AGED UNDER 18 OR OVER 64  PER CAPITA INCOME
# 0                               38.5               23040
# 1                               25.5               37524
# 2                               26.2               57123
# 3                               17.0               60058
# 4                               21.5               71551
# ..                               ...                 ...
# 71                              36.8               34381
# 72                              40.3               27149
# 73                              30.3               25828
# 74                              23.8               33385
# 75                              33.5               28202
#
# [76 rows x 7 columns]

# %%
file_path2 = "Resources/NSICA.csv"
#Neighborhood Safety
NSICA_df= pd.read_csv(file_path2)
NSICA_df
# Out:
#    Category  Full population
# 0      2015        1578000.0
# 1      2016        1494000.0
# 2      2017        1613000.0
# 3      2018        1629000.0
# 4      2019              NaN
# 5      2020        1364000.0
# 6      2021        1298000.0

# %%
file_path3 = "Resources/CBICA.csv"
#Community Belonging in Chicago All Ages
belonging_df= pd.read_csv(file_path3)
belonging_df
# Out:
#    Category  Full population
# 0      2015        1358000.0
# 1      2016        1245000.0
# 2      2017        1255000.0
# 3      2018        1324000.0
# 4      2019              NaN
# 5      2020         970000.0
# 6      2021         923000.0

# %%
file_path4 = "Resources/SSRIC.csv"
#School Safety Rate
safety_df= pd.read_csv(file_path4)
safety_df
# Out:
#    Category  Full population
# 0      2001             16.0
# 1      2003             13.6
# 2      2005             10.5
# 3      2007             12.3
# 4      2009             15.1
# 5      2011             10.8
# 6      2013             12.9
# 7      2015              NaN
# 8      2017             10.0
# 9      2019             12.8

# %%
file_path5 = "Resources/SFRIC.csv"
SFRIC_df= pd.read_csv(file_path5)
SFRIC_df.head()
# Out:
#    Category  Full population
# 0      2001             18.5
# 1      2003             19.3
# 2      2005             19.5
# 3      2007             17.4
# 4      2009             20.6

# %%
file_path6 = "Resources/SBRIC.csv"
SBRIC_df= pd.read_csv(file_path6)
SBRIC_df.head()
# Out:
#    Category  Full population
# 0      2009             11.1
# 1      2011             12.8
# 2      2013             13.0
# 3      2015              NaN
# 4      2017             15.2

# %%
plt.rcParams['figure.figsize'] = [19, 7]
cleaned_CSSEMH.plot(kind='bar',x='COMMUNITY AREA NAME',y='PERCENT HOUSEHOLDS BELOW POVERTY', color='red')
plt.title("Poverty Rate by Neighborhood")
plt.show()

# %%
ax = plt.gca()
cleaned_CSSEMH.plot(kind='line',x='COMMUNITY AREA NAME',y='PERCENT HOUSEHOLDS BELOW POVERTY',ax=ax)
cleaned_CSSEMH.plot(kind='line',x='COMMUNITY AREA NAME',y='PERCENT AGED 25+ WITHOUT HIGH SCHOOL DIPLOMA', color='red', ax=ax)
plt.title("Households % Below Poverty vs Household % highschool dropouts ")
plt.savefig('Images/DEEZ1.png',format='png')
plt.show()

# %%
ax = plt.gca()
belonging_df.plot(kind='line',x='Category',y='Full population',ax=ax)
NSICA_df.plot(kind='line',x='Category',y='Full population', color='red', ax=ax)
plt.xlabel("Year")
plt.ylabel("Full Population (In Millions)")
plt.legend(['Community Belongng','Neighborhood safety'],loc='best')
plt.title("Community Belonging vs Neighborhood Safety")
plt.savefig('Images/DEEZ2.png',format='png')
plt.show()

# %%
ax = plt.gca()
SFRIC_df.plot(kind='line',x='Category',y='Full population',ax=ax)
safety_df.plot(kind='line',x='Category',y='Full population', color='red', ax=ax)
SBRIC_df.plot(kind='line',x='Category',y='Full population', color='Green', ax=ax)
plt.xlabel("Year")
plt.ylabel("Students(%)")
plt.legend(['School Fights','School Safety Ovr','School Bullying'],loc='best')
plt.title("School fights, School Bullying vs Overall School Safety")
plt.savefig('Images/DEEZ3.png',format='png')
plt.show()
